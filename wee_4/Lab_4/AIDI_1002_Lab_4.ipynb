# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# **Loading Data**

# %%
df_clean_tech = pd.read_csv('CAIT 2.0 Country Clean Technology Data-csv.csv')
df_clean_tech.reset_index(drop=True,inplace=True)
df_clean_tech.columns = df_clean_tech.iloc[0]
df_clean_tech = df_clean_tech.loc[1:]
df_clean_tech = df_clean_tech.reset_index(drop=True)
df_clean_tech.head(10)
# Out:
# 0 Country  Year Cumulative Installed Solar PV Capacity (MW)  \
# 0   China  2000                                         NaN
# 1   China  2001                                         NaN
# 2   China  2002                                         NaN
# 3   China  2003                                         NaN
# 4   China  2004                                        62.1
# 5   China  2005                                          71
# 6   China  2006                                          81
# 7   China  2007                                         101
# 8   China  2008                                         141
# 9   China  2009                                         351
#
# 0 Annual Additions of Installed Solar PV Capacity (MW)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                 10
# 5                                                8.9
# 6                                                 10
# 7                                                 20
# 8                                                 40
# 9                                                210
#
# 0 Cumulative Installed Wind Capacity (MW)  \
# 0                                     346
# 1                                     402
# 2                                     469
# 3                                     567
# 4                                     764
# 5                                    1260
# 6                                    2559
# 7                                    5910
# 8                                   12020
# 9                                   25805
#
# 0 Annual Additions of Installed Wind Capacity (MW)  \
# 0                                              NaN
# 1                                               56
# 2                                               67
# 3                                               98
# 4                                              197
# 5                                              496
# 6                                             1299
# 7                                             3351
# 8                                             6110
# 9                                            13785
#
# 0 Annual Manufacturing Capacity of Silicon (Metric Tons)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# 5                                                NaN
# 6                                                NaN
# 7                                               1500
# 8                                               4500
# 9                                              26000
#
# 0 Annual Manufacturing Capacity of PV Cells (MW)  \
# 0                                            NaN
# 1                                            NaN
# 2                                            NaN
# 3                                            NaN
# 4                                            NaN
# 5                                            253
# 6                                            893
# 7                                           2361
# 8                                           5101
# 9                                           7011
#
# 0 Annual Manufacturing Capacity of PV Modules (MW)  \
# 0                                              NaN
# 1                                              NaN
# 2                                              NaN
# 3                                              NaN
# 4                                              NaN
# 5                                              373
# 6                                           1054.5
# 7                                             2597
# 8                                             4470
# 9                                             7640
#
# 0 Annual Manufacturing Capacity of Wind Turbines (MW) Total Solar PV Jobs  \
# 0                                                NaN                  NaN
# 1                                                NaN                  NaN
# 2                                                NaN                  NaN
# 3                                                NaN                  NaN
# 4                                                NaN                  NaN
# 5                                              781.5                  NaN
# 6                                             1254.5                39500
# 7                                             4683.4                82800
# 8                                           10935.75               200000
# 9                                              23168               220000
#
# 0 Total Solar PV Manufacturing Jobs Total Wind Jobs  \
# 0                               NaN             NaN
# 1                               NaN             NaN
# 2                               NaN             NaN
# 3                               NaN             NaN
# 4                               NaN             NaN
# 5                               NaN             NaN
# 6                               NaN             NaN
# 7                               NaN             NaN
# 8                               NaN             NaN
# 9                               NaN          150000
#
# 0 Total Wind Manufacturing Jobs
# 0                           NaN
# 1                           NaN
# 2                           NaN
# 3                           NaN
# 4                           NaN
# 5                           NaN
# 6                           NaN
# 7                           NaN
# 8                           NaN
# 9                           NaN

# %%
df_clean_fuel = pd.read_csv('cleanFuelAndTech.csv')
df_clean_tech.head(10)
# Out:
#   Unnamed: 0 Unnamed: 1                                     Capacity  \
# 0    Country       Year  Cumulative Installed Solar PV Capacity (MW)
# 1      China       2000                                          NaN
# 2      China       2001                                          NaN
# 3      China       2002                                          NaN
# 4      China       2003                                          NaN
# 5      China       2004                                         62.1
# 6      China       2005                                           71
# 7      China       2006                                           81
# 8      China       2007                                          101
# 9      China       2008                                          141
#
#                                           Unnamed: 3  \
# 0  Annual Additions of Installed Solar PV Capacit...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# 5                                                 10
# 6                                                8.9
# 7                                                 10
# 8                                                 20
# 9                                                 40
#
#                                 Unnamed: 4  \
# 0  Cumulative Installed Wind Capacity (MW)
# 1                                      346
# 2                                      402
# 3                                      469
# 4                                      567
# 5                                      764
# 6                                     1260
# 7                                     2559
# 8                                     5910
# 9                                    12020
#
#                                          Unnamed: 5  \
# 0  Annual Additions of Installed Wind Capacity (MW)
# 1                                               NaN
# 2                                                56
# 3                                                67
# 4                                                98
# 5                                               197
# 6                                               496
# 7                                              1299
# 8                                              3351
# 9                                              6110
#
#                               Manufacturing Capacity  \
# 0  Annual Manufacturing Capacity of Silicon (Metr...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# 5                                                NaN
# 6                                                NaN
# 7                                                NaN
# 8                                               1500
# 9                                               4500
#
#                                        Unnamed: 7  \
# 0  Annual Manufacturing Capacity of PV Cells (MW)
# 1                                             NaN
# 2                                             NaN
# 3                                             NaN
# 4                                             NaN
# 5                                             NaN
# 6                                             253
# 7                                             893
# 8                                            2361
# 9                                            5101
#
#                                          Unnamed: 8  \
# 0  Annual Manufacturing Capacity of PV Modules (MW)
# 1                                               NaN
# 2                                               NaN
# 3                                               NaN
# 4                                               NaN
# 5                                               NaN
# 6                                               373
# 7                                            1054.5
# 8                                              2597
# 9                                              4470
#
#                                           Unnamed: 9                 Jobs  \
# 0  Annual Manufacturing Capacity of Wind Turbines...  Total Solar PV Jobs
# 1                                                NaN                  NaN
# 2                                                NaN                  NaN
# 3                                                NaN                  NaN
# 4                                                NaN                  NaN
# 5                                                NaN                  NaN
# 6                                              781.5                  NaN
# 7                                             1254.5                39500
# 8                                             4683.4                82800
# 9                                           10935.75               200000
#
#                          Unnamed: 11      Unnamed: 12  \
# 0  Total Solar PV Manufacturing Jobs  Total Wind Jobs
# 1                                NaN              NaN
# 2                                NaN              NaN
# 3                                NaN              NaN
# 4                                NaN              NaN
# 5                                NaN              NaN
# 6                                NaN              NaN
# 7                                NaN              NaN
# 8                                NaN              NaN
# 9                                NaN              NaN
#
#                      Unnamed: 13
# 0  Total Wind Manufacturing Jobs
# 1                            NaN
# 2                            NaN
# 3                            NaN
# 4                            NaN
# 5                            NaN
# 6                            NaN
# 7                            NaN
# 8                            NaN
# 9                            NaN

# %%
df_cont = pd.read_csv('continents2.csv')
df_cont.head(10)
# Out:
#                   name alpha-2 alpha-3  country-code     iso_3166-2    region  \
# 0          Afghanistan      AF     AFG             4  ISO 3166-2:AF      Asia
# 1        Åland Islands      AX     ALA           248  ISO 3166-2:AX    Europe
# 2              Albania      AL     ALB             8  ISO 3166-2:AL    Europe
# 3              Algeria      DZ     DZA            12  ISO 3166-2:DZ    Africa
# 4       American Samoa      AS     ASM            16  ISO 3166-2:AS   Oceania
# 5              Andorra      AD     AND            20  ISO 3166-2:AD    Europe
# 6               Angola      AO     AGO            24  ISO 3166-2:AO    Africa
# 7             Anguilla      AI     AIA           660  ISO 3166-2:AI  Americas
# 8           Antarctica      AQ     ATA            10  ISO 3166-2:AQ       NaN
# 9  Antigua and Barbuda      AG     ATG            28  ISO 3166-2:AG  Americas
#
#                         sub-region intermediate-region  region-code  \
# 0                    Southern Asia                 NaN        142.0
# 1                  Northern Europe                 NaN        150.0
# 2                  Southern Europe                 NaN        150.0
# 3                  Northern Africa                 NaN          2.0
# 4                        Polynesia                 NaN          9.0
# 5                  Southern Europe                 NaN        150.0
# 6               Sub-Saharan Africa       Middle Africa          2.0
# 7  Latin America and the Caribbean           Caribbean         19.0
# 8                              NaN                 NaN          NaN
# 9  Latin America and the Caribbean           Caribbean         19.0
#
#    sub-region-code  intermediate-region-code
# 0             34.0                       NaN
# 1            154.0                       NaN
# 2             39.0                       NaN
# 3             15.0                       NaN
# 4             61.0                       NaN
# 5             39.0                       NaN
# 6            202.0                      17.0
# 7            419.0                      29.0
# 8              NaN                       NaN
# 9            419.0                      29.0

# %% [markdown]
# #### Description of the columns

# %% [markdown]
# **CAIT 2.0 Country Clean Tech Data Set**
# - Country: Country Name
# - Year: year
# - Cumulaive Installed Solar PV Capacity (MW): Cumulative amount energy can be produced by the solar system
# - Annual Additions of Installed Solar PV Capacity (MW): the additional amount of energy that can be produced by solar system compare to last year
# - Annual Manufacturing capacity of Sillicon (Metric Tons): amount of silicon can be produced in a year
# - Annual Manufacturing Capacity of PV Cells (MW): the number of photovoltaic cells that can be produced in a year based on the amount of energy they can produce
# - Annual Manufacturing Capacity of PV modules (MW): number of photovoltaic modules that can be manufactured in a year based on the amount of energy the would produce
# - Annual Manufacturing of Wind Turbines (MW): the number of wind turbines that can be producecd in a year based on the amount of energy they output
# - Total Solar PV Jobs: total number of solar photovoltaic jobs
# - Total Wind Jobs: total number of wind energy jobs
# - Total Manufacturing Jobs: total number of turbine manufacturing jobs
#
# **cleanFuelAndTech Data Set**
# - country: Country Name
# - Indicator: Description of what the tooltip indicates
# - Period: Year
# - Tooltip: percentage of clean fuel usage
#
# **continents2 Data Set**
# - name: country name
# - alpha-2: alpha-2 code
# - alpha-3: alpha-3 code
# - country-code: numeric code
# - iso_3166_2: codes for identifying the principal subdivisions of all countries
# - region: continent
# - sub-region: sub-continent
# - intermediate-region: divisions of the region
# - regions-code: continent code
# - sub-region-code: sub-continent code
# - intermediate-region code: code for divions of the region

# %% [markdown]
# **We will check the description of the data for each country**

# %%
df_clean_tech['Country'].unique()
# Out:
# array(['China', 'Germany', 'India', 'Japan', 'United States'],
#       dtype=object)

# %%
# Seperating data based on country
df_cl_tech_china = df_clean_tech.loc[df_clean_tech.Country=='China']
df_cl_tech_china = df_cl_tech_china.reset_index(drop=True)
df_cl_tech_germany = df_clean_tech.loc[df_clean_tech.Country=='Germany']
df_cl_tech_germany = df_cl_tech_germany.reset_index(drop=True)
df_cl_tech_india = df_clean_tech.loc[df_clean_tech.Country=='India']
df_cl_tech_india = df_cl_tech_india.reset_index(drop=True)
df_cl_tech_japan = df_clean_tech.loc[df_clean_tech.Country=='Japan']
df_cl_tech_japan = df_cl_tech_japan.reset_index(drop=True)
df_cl_tech_us = df_clean_tech.loc[df_clean_tech.Country=='United States']
df_cl_tech_us = df_cl_tech_us.reset_index(drop=True)

# %%
df_cl_tech_china.describe()
# Out:
# 0      Country  Year Cumulative Installed Solar PV Capacity (MW)  \
# count       12    12                                           8
# unique       1    12                                           8
# top      China  2000                                        62.1
# freq        12     1                                           1
#
# 0      Annual Additions of Installed Solar PV Capacity (MW)  \
# count                                                   8
# unique                                                  7
# top                                                    10
# freq                                                    2
#
# 0      Cumulative Installed Wind Capacity (MW)  \
# count                                       12
# unique                                      12
# top                                        346
# freq                                         1
#
# 0      Annual Additions of Installed Wind Capacity (MW)  \
# count                                                11
# unique                                               11
# top                                                  56
# freq                                                  1
#
# 0      Annual Manufacturing Capacity of Silicon (Metric Tons)  \
# count                                                   5
# unique                                                  5
# top                                                  1500
# freq                                                    1
#
# 0      Annual Manufacturing Capacity of PV Cells (MW)  \
# count                                               7
# unique                                              7
# top                                               253
# freq                                                1
#
# 0      Annual Manufacturing Capacity of PV Modules (MW)  \
# count                                                 7
# unique                                                7
# top                                                 373
# freq                                                  1
#
# 0      Annual Manufacturing Capacity of Wind Turbines (MW)  \
# count                                                   7
# unique                                                  7
# top                                                 781.5
# freq                                                    1
#
# 0      Total Solar PV Jobs Total Solar PV Manufacturing Jobs Total Wind Jobs  \
# count                    5                                 0               1
# unique                   5                                 0               1
# top                  39500                               NaN          150000
# freq                     1                               NaN               1
#
# 0      Total Wind Manufacturing Jobs
# count                              0
# unique                             0
# top                              NaN
# freq                             NaN

# %%
df_cl_tech_germany.describe()
# Out:
# 0       Country  Year Cumulative Installed Solar PV Capacity (MW)  \
# count        12    12                                          12
# unique        1    12                                          12
# top     Germany  2000                                          76
# freq         12     1                                           1
#
# 0      Annual Additions of Installed Solar PV Capacity (MW)  \
# count                                                  12
# unique                                                 12
# top                                                    45
# freq                                                    1
#
# 0      Cumulative Installed Wind Capacity (MW)  \
# count                                       12
# unique                                      12
# top                                       6095
# freq                                         1
#
# 0      Annual Additions of Installed Wind Capacity (MW)  \
# count                                                12
# unique                                               11
# top                                                1665
# freq                                                  2
#
# 0      Annual Manufacturing Capacity of Silicon (Metric Tons)  \
# count                                                   7
# unique                                                  7
# top                                                  5500
# freq                                                    1
#
# 0      Annual Manufacturing Capacity of PV Cells (MW)  \
# count                                               7
# unique                                              7
# top                                                 6
# freq                                                1
#
# 0      Annual Manufacturing Capacity of PV Modules (MW)  \
# count                                                 7
# unique                                                7
# top                                                  21
# freq                                                  1
#
# 0      Annual Manufacturing Capacity of Wind Turbines (MW)  \
# count                                                   7
# unique                                                  7
# top                                                  4080
# freq                                                    1
#
# 0      Total Solar PV Jobs Total Solar PV Manufacturing Jobs Total Wind Jobs  \
# count                   12                                 0              12
# unique                  12                                 0              12
# top                   3100                               NaN           25000
# freq                     1                               NaN               1
#
# 0      Total Wind Manufacturing Jobs
# count                              7
# unique                             6
# top                            37000
# freq                               2

# %%
df_cl_tech_india.describe()
# Out:
# 0      Country  Year Cumulative Installed Solar PV Capacity (MW)  \
# count       12    12                                           7
# unique       1    12                                           6
# top      India  2000                                        2.12
# freq        12     1                                           2
#
# 0      Annual Additions of Installed Solar PV Capacity (MW)  \
# count                                                   3
# unique                                                  3
# top                                                   6.1
# freq                                                    1
#
# 0      Cumulative Installed Wind Capacity (MW)  \
# count                                       12
# unique                                      12
# top                                        220
# freq                                         1
#
# 0      Annual Additions of Installed Wind Capacity (MW)  \
# count                                                11
# unique                                               11
# top                                                1236
# freq                                                  1
#
# 0      Annual Manufacturing Capacity of Silicon (Metric Tons)  \
# count                                                   0
# unique                                                  0
# top                                                   NaN
# freq                                                  NaN
#
# 0      Annual Manufacturing Capacity of PV Cells (MW)  \
# count                                               7
# unique                                              7
# top                                              20.5
# freq                                                1
#
# 0      Annual Manufacturing Capacity of PV Modules (MW)  \
# count                                                 7
# unique                                                7
# top                                                66.5
# freq                                                  1
#
# 0      Annual Manufacturing Capacity of Wind Turbines (MW)  \
# count                                                   7
# unique                                                  6
# top                                                  3055
# freq                                                    2
#
# 0      Total Solar PV Jobs Total Solar PV Manufacturing Jobs Total Wind Jobs  \
# count                    1                                 0               1
# unique                   1                                 0               1
# top                 112000                               NaN           42000
# freq                     1                               NaN               1
#
# 0      Total Wind Manufacturing Jobs
# count                              0
# unique                             0
# top                              NaN
# freq                             NaN

# %%
df_cl_tech_japan.describe()
# Out:
# 0      Country  Year Cumulative Installed Solar PV Capacity (MW)  \
# count       12    12                                          12
# unique       1    12                                          12
# top      Japan  2000                                       330.2
# freq        12     1                                           1
#
# 0      Annual Additions of Installed Solar PV Capacity (MW)  \
# count                                                  11
# unique                                                 11
# top                                                 122.6
# freq                                                    1
#
# 0      Cumulative Installed Wind Capacity (MW)  \
# count                                       12
# unique                                      12
# top                                        136
# freq                                         1
#
# 0      Annual Additions of Installed Wind Capacity (MW)  \
# count                                                11
# unique                                                9
# top                                                 167
# freq                                                  2
#
# 0      Annual Manufacturing Capacity of Silicon (Metric Tons)  \
# count                                                   7
# unique                                                  6
# top                                                  8300
# freq                                                    2
#
# 0      Annual Manufacturing Capacity of PV Cells (MW)  \
# count                                               7
# unique                                              7
# top                                               551
# freq                                                1
#
# 0      Annual Manufacturing Capacity of PV Modules (MW)  \
# count                                                 7
# unique                                                7
# top                                                 688
# freq                                                  1
#
# 0      Annual Manufacturing Capacity of Wind Turbines (MW)  \
# count                                                   7
# unique                                                  6
# top                                                  2040
# freq                                                    2
#
# 0      Total Solar PV Jobs Total Solar PV Manufacturing Jobs Total Wind Jobs  \
# count                    6                                 6               0
# unique                   6                                 6               0
# top                   9800                              2500             NaN
# freq                     1                                 1             NaN
#
# 0      Total Wind Manufacturing Jobs
# count                              0
# unique                             0
# top                              NaN
# freq                             NaN

# %%
df_cl_tech_us.describe()
# Out:
# 0             Country  Year Cumulative Installed Solar PV Capacity (MW)  \
# count              12    12                                          10
# unique              1    12                                          10
# top     United States  2000                                          28
# freq               12     1                                           1
#
# 0      Annual Additions of Installed Solar PV Capacity (MW)  \
# count                                                   9
# unique                                                  9
# top                                                    45
# freq                                                    1
#
# 0      Cumulative Installed Wind Capacity (MW)  \
# count                                       12
# unique                                      12
# top                                       2578
# freq                                         1
#
# 0      Annual Additions of Installed Wind Capacity (MW)  \
# count                                                11
# unique                                               11
# top                                                1697
# freq                                                  1
#
# 0      Annual Manufacturing Capacity of Silicon (Metric Tons)  \
# count                                                   7
# unique                                                  5
# top                                                 21900
# freq                                                    2
#
# 0      Annual Manufacturing Capacity of PV Cells (MW)  \
# count                                               6
# unique                                              5
# top                                               125
# freq                                                2
#
# 0      Annual Manufacturing Capacity of PV Modules (MW)  \
# count                                                 7
# unique                                                7
# top                                                  90
# freq                                                  1
#
# 0      Annual Manufacturing Capacity of Wind Turbines (MW)  \
# count                                                   7
# unique                                                  6
# top                                                  1200
# freq                                                    2
#
# 0      Total Solar PV Jobs Total Solar PV Manufacturing Jobs Total Wind Jobs  \
# count                    9                                 4               0
# unique                   9                                 4               0
# top                   1100                               705             NaN
# freq                     1                                 1             NaN
#
# 0      Total Wind Manufacturing Jobs
# count                              0
# unique                             0
# top                              NaN
# freq                             NaN

# %%
countries_dfs = [df_cl_tech_china,
                 df_cl_tech_germany,
                 df_cl_tech_japan, 
                 df_cl_tech_us,
                 df_cl_tech_india]

# %% [markdown]
# **Different countnries clean energy comparison Stacked Barplot**

# %%
df_clean_tech.columns
# Out:
# Index(['Country', 'Year', 'Cumulative Installed Solar PV Capacity (MW)',
#        'Annual Additions of Installed Solar PV Capacity (MW)',
#        'Cumulative Installed Wind Capacity (MW)',
#        'Annual Additions of Installed Wind Capacity (MW)',
#        'Annual Manufacturing Capacity of Silicon (Metric Tons)',
#        'Annual Manufacturing Capacity of PV Cells (MW)',
#        'Annual Manufacturing Capacity of PV Modules (MW)',
#        'Annual Manufacturing Capacity of Wind Turbines (MW)',
#        'Total Solar PV Jobs', 'Total Solar PV Manufacturing Jobs',
#        'Total Wind Jobs', 'Total Wind Manufacturing Jobs'],
#       dtype='object', name=0)

# %%
pivot_clean_tech = pd.pivot_table(data=df_clean_tech,
                                  index=['Year'],
                                  columns=['Country'],
                                  values='Cumulative Installed Solar PV Capacity (MW)'
                                 )
pivot_clean_tech.fillna(pivot_clean_tech.mean(),inplace=True)
pivot_clean_tech.head(10)
# Out:
# Country     China  Germany      India   Japan  United States
# Year
# 2000     603.3875     76.0  76.125714   330.2          926.9
# 2001     603.3875    186.0  76.125714   452.8          926.9
# 2002     603.3875    296.0  76.125714   636.8           28.0
# 2003     603.3875    435.0  76.125714   859.6           73.0
# 2004      62.1000   1105.0  76.125714  1132.0          131.0
# 2005      71.0000   2056.0   2.740000  1421.9          201.0
# 2006      81.0000   2899.0   2.920000  1708.5          315.0
# 2007     101.0000   4170.0   2.120000  1918.9          475.0
# 2008     141.0000   6120.0   2.120000  2144.2          773.0
# 2009     351.0000   9914.0   9.130000  2627.2         1208.0

# %%
pivot_clean_tech.columns
# Out:
# Index(['China', 'Germany', 'India', 'Japan', 'United States'], dtype='object', name='Country')

# %%
ax = pivot_clean_tech.plot.bar(stacked=True,
                               figsize=(12,10)
                              )
ax.set_title('The Number of Students',fontsize=20)
ax.set_ylim(0,40000)
ax.set_xticklabels(['China','Germany','India', 'Japan', 'United States'], rotation=0)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In [70], line 6
#       4 ax.set_title('The Number of Students',fontsize=20)
#       5 ax.set_ylim(0,40000)
# ----> 6 ax.set_xticklabels(['China','Germany','India', 'Japan', 'United States'], rotation=0)
#
# File ~/.local/lib/python3.10/site-packages/matplotlib/axes/_base.py:73, in _axis_method_wrapper.__set_name__.<locals>.wrapper(self, *args, **kwargs)
#      72 def wrapper(self, *args, **kwargs):
# ---> 73     return get_method(self)(*args, **kwargs)
#
# File ~/.local/lib/python3.10/site-packages/matplotlib/axis.py:1968, in Axis._set_ticklabels(self, labels, fontdict, minor, **kwargs)
#    1966 if fontdict is not None:
#    1967     kwargs.update(fontdict)
# -> 1968 return self.set_ticklabels(labels, minor=minor, **kwargs)
#
# File ~/.local/lib/python3.10/site-packages/matplotlib/axis.py:1890, in Axis.set_ticklabels(self, ticklabels, minor, **kwargs)
#    1886 if isinstance(locator, mticker.FixedLocator):
#    1887     # Passing [] as a list of ticklabels is often used as a way to
#    1888     # remove all tick labels, so only error for > 0 ticklabels
#    1889     if len(locator.locs) != len(ticklabels) and len(ticklabels) != 0:
# -> 1890         raise ValueError(
#    1891             "The number of FixedLocator locations"
#    1892             f" ({len(locator.locs)}), usually from a call to"
#    1893             " set_ticks, does not match"
#    1894             f" the number of ticklabels ({len(ticklabels)}).")
#    1895     tickd = {loc: lab for loc, lab in zip(locator.locs, ticklabels)}
#    1896     func = functools.partial(self._format_with_dict, tickd)
#
# ValueError: The number of FixedLocator locations (12), usually from a call to set_ticks, does not match the number of ticklabels (5).
